# %%
import untitled

# %%
untitled.f(2)

# %%
from ipywidgets import interactive, fixed

# %%
w=interactive(untitled.f,a = (0.0,10.0))
w
# Out:
# interactive(children=(FloatSlider(value=2.0, description='a', max=10.0), Output()), _dom_classes=('widget-inte…
